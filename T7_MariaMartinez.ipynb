# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFzQj91sOlkeDFkg5HDbjtR4QJYmLXkfMNig&usqp=CAU" width="400" height="500" />
#
#
# ### <font color='navy'> Simulación matemática.
#
# **Nombres:** María del Carmen Martínez Hernández.
#
# **Fecha:** 12 de octubre de 2022.
#
# **Expediente** : NT729340.
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/MMHdez/T7_MariaMartinez
#
# # Tarea 7: Clase 11

# %% [markdown]
# **Actividad** La actividad consiste en generar el helecho mutante con los coeficientes de esta nueva tabla.
#
# Hacer un nuevo archivo de jupyter (extensión .ipynb) con el nombre *T7_PrimerNombrePrimerApellido* y subirlo en el enlace habilitado.

# %%
# Importar librerías para graficas y números aleatorios
import matplotlib.pyplot as plt
import random

# Importar pandas y numpy
import pandas as pd
import numpy as np

# %%
i = np.arange(0,4)
i = np.arange(0,4)

df = pd.DataFrame(index=i,columns=['ai', 'bi', 'ci', 'di', 'ei', 'fi', 'pi', 'Porción generada'], dtype='float')
df.index.name = "$i$"

df['ai'] = [0.0, 0.85, 0.09, -0.09]
df['bi'] = [0.0, 0.02, -0.28, 0.28]
df['ci'] = [0.0, -0.02, 0.3, 0.3]
df['di'] = [0.25, 0.83, 0.11, 0.09]
df['ei'] = [0.0, 0.0, 0.0, 0.0]
df['fi'] = [-0.14, 1.0, 0.6, 0.7]
df['pi'] = [0.02, 0.84, 0.07, 0.07]
df['Porción generada'] = ['Tallo', 'Follaje cada vez más pequeño', 'Ramas izquierda', 'Ramas derecha']

df.round(3)
# Out:
#        ai    bi    ci    di   ei    fi    pi              Porción generada
# $i$
# 0    0.00  0.00  0.00  0.25  0.0 -0.14  0.02                         Tallo
# 1    0.85  0.02 -0.02  0.83  0.0  1.00  0.84  Follaje cada vez más pequeño
# 2    0.09 -0.28  0.30  0.11  0.0  0.60  0.07               Ramas izquierda
# 3   -0.09  0.28  0.30  0.09  0.0  0.70  0.07                 Ramas derecha

# %%
# Crear la matriz de Barnsley
Mat_Culcita = df.iloc[:,:-1].values
Mat_Culcita
# Out:
# array([[ 0.  ,  0.  ,  0.  ,  0.25,  0.  , -0.14,  0.02],
#        [ 0.85,  0.02, -0.02,  0.83,  0.  ,  1.  ,  0.84],
#        [ 0.09, -0.28,  0.3 ,  0.11,  0.  ,  0.6 ,  0.07],
#        [-0.09,  0.28,  0.3 ,  0.09,  0.  ,  0.7 ,  0.07]])

# %%
x = [0]
y = [0]

# Generar los valores de i con su probabilidad
seq = [0,1,2,3]
prob = Mat_Culcita[:,-1]
a = Mat_Culcita[:,0]
b = Mat_Culcita[:,1]
c = Mat_Culcita[:,2]
d = Mat_Culcita[:,3]
e = Mat_Culcita[:,4]
f = Mat_Culcita[:,5]

# Graficar
for k in range(100000):
    i = random.choices(seq,prob)
    x.append(a[i]*x[k] + b[i]*y[k] + e[i])
    y.append(c[i]*x[k] + d[i]*y[k] + f[i])
    
plt.figure(figsize=(8,8)) 
plt.scatter(x,y,c='g',s=0.3)
plt.show()
# Out:
# C:\Users\hdezm\anaconda3\lib\site-packages\numpy\ma\core.py:2829: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   _data = np.array(data, dtype=dtype, copy=copy,

# %% [markdown]
# **Conclusión:** La nueva mutación Culcita posee una menor cantidad de hojas de mayor anchura; así como también una elongación del tallo hacia arriba sobre la parte superior. Es una combinación entre el fractal helecho de Barnsley y de la mutación Cyclosorus.
